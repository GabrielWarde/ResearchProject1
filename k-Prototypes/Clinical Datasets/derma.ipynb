# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, adjusted_rand_score

def euclidean_distance(point1, point2):
    return np.sqrt(np.sum((point1 - point2) ** 2))

def simple_matching_distance(point1, point2):
    return np.sum(point1 != point2)

def initialize_prototypes(preprocessed_data, n_clusters):
    numerical_indices = np.random.choice(len(preprocessed_data), n_clusters, replace=False)
    categorical_indices = np.random.choice(len(preprocessed_data), n_clusters, replace=False)
    numerical_prototypes = preprocessed_data[whichnum].iloc[numerical_indices].values
    categorical_prototypes = preprocessed_data[whichcat].iloc[categorical_indices].values
    return numerical_prototypes, categorical_prototypes

def assign_clusters(preprocessed_data, numerical_prototypes, categorical_prototypes, gamma):
    assigned_clusters = []
    for _, row in preprocessed_data.iterrows():
        distances = []
        for num_proto, cat_proto in zip(numerical_prototypes, categorical_prototypes):
            num_distance = euclidean_distance(row[whichnum], num_proto)
            cat_distance = simple_matching_distance(row[whichcat], cat_proto)
            total_distance = num_distance + gamma * cat_distance
            distances.append(total_distance)
        assigned_clusters.append(np.argmin(distances))
    return assigned_clusters

def update_prototypes(preprocessed_data, assigned_clusters, n_clusters):
    new_numerical_prototypes = []
    new_categorical_prototypes = []
    
    for cluster in range(n_clusters):
        cluster_indices = [i for i, c in enumerate(assigned_clusters) if c == cluster]
        cluster_data = preprocessed_data.iloc[cluster_indices]
        new_numerical_prototype = cluster_data[whichnum].mean(axis=0)
        new_categorical_prototype = cluster_data[whichcat].mode(axis=0).iloc[0]
        new_numerical_prototypes.append(new_numerical_prototype)
        new_categorical_prototypes.append(new_categorical_prototype)
    
    return np.array(new_numerical_prototypes), np.array(new_categorical_prototypes)

def k_prototypes(preprocessed_data, n_clusters, max_iterations=100, tol=1e-5):
    numerical_prototypes, categorical_prototypes = initialize_prototypes(preprocessed_data, n_clusters)
    
    for _ in range(max_iterations):
        assigned_clusters = assign_clusters(preprocessed_data, numerical_prototypes, categorical_prototypes, gamma)
        
        new_numerical_prototypes, new_categorical_prototypes = update_prototypes(preprocessed_data, assigned_clusters, n_clusters)
        
        if np.allclose(numerical_prototypes, new_numerical_prototypes, atol=tol) and np.allclose(categorical_prototypes, new_categorical_prototypes, atol=tol):
            break
        
        numerical_prototypes = new_numerical_prototypes
        categorical_prototypes = new_categorical_prototypes
    
    return assigned_clusters, numerical_prototypes, categorical_prototypes

def align_clusters(clusters, true_labels):
    unique_clusters = np.unique(clusters)
    aligned_clusters = np.zeros_like(clusters)
    for cluster in unique_clusters:
        true_label = pd.Series(true_labels[clusters == cluster]).mode()[0]
        aligned_clusters[clusters == cluster] = true_label
    return aligned_clusters


data = pd.read_csv('Dermatology.csv')
truelabels =data['class']
data.drop(['class'], axis=1, inplace=True)

# Separating numerical and categorical columns
numerical_cols = data[['age','erythema','scaling','definite_borders','itching','koebner_phenomenon','polygonal_papules','follicular_papules','oral_mucosal_involvement','knee_and_elbow_involvement','scalp_involvement','melanin_incontinence','eosinophils_in_the_infiltrate','pnl_infiltrate','fibrosis_of_the_papillary_dermis','exocytosis','acanthosis','hyperkeratosis','parakeratosis','clubbing_of_the_rete_ridges','elongation_of_the_rete_ridges','thinning_of_the_suprapapillary_epidermis','spongiform_pustule','munro_microabcess','focal_hypergranulosis','disappearance_of_the_granular_layer','vacuolisation_and_damage_of_basal_layer','spongiosis','saw-tooth_appearance_of_retes','follicular_horn_plug','perifollicular_parakeratosis','inflammatory_monoluclear_inflitrate','band-like_infiltrate']].copy()
categorical_cols = data.drop(['age','erythema','scaling','definite_borders','itching','koebner_phenomenon','polygonal_papules','follicular_papules','oral_mucosal_involvement','knee_and_elbow_involvement','scalp_involvement','melanin_incontinence','eosinophils_in_the_infiltrate','pnl_infiltrate','fibrosis_of_the_papillary_dermis','exocytosis','acanthosis','hyperkeratosis','parakeratosis','clubbing_of_the_rete_ridges','elongation_of_the_rete_ridges','thinning_of_the_suprapapillary_epidermis','spongiform_pustule','munro_microabcess','focal_hypergranulosis','disappearance_of_the_granular_layer','vacuolisation_and_damage_of_basal_layer','spongiosis','saw-tooth_appearance_of_retes','follicular_horn_plug','perifollicular_parakeratosis','inflammatory_monoluclear_inflitrate','band-like_infiltrate'], axis=1).copy()

preprocessed_data = pd.concat([numerical_cols, categorical_cols], axis=1)

whichnum = ['age','erythema','scaling','definite_borders','itching','koebner_phenomenon','polygonal_papules','follicular_papules','oral_mucosal_involvement','knee_and_elbow_involvement','scalp_involvement','melanin_incontinence','eosinophils_in_the_infiltrate','pnl_infiltrate','fibrosis_of_the_papillary_dermis','exocytosis','acanthosis','hyperkeratosis','parakeratosis','clubbing_of_the_rete_ridges','elongation_of_the_rete_ridges','thinning_of_the_suprapapillary_epidermis','spongiform_pustule','munro_microabcess','focal_hypergranulosis','disappearance_of_the_granular_layer','vacuolisation_and_damage_of_basal_layer','spongiosis','saw-tooth_appearance_of_retes','follicular_horn_plug','perifollicular_parakeratosis','inflammatory_monoluclear_inflitrate','band-like_infiltrate']
whichcat= [col for col in data.columns if col not in whichnum]
n_clusters = 6
accuracy_scores = []
rand_index_scores = []
num_runs = 50
gamma=0.5
for _ in range(num_runs):
    assignedclusters, numerical_prototypes, categorical_prototypes = k_prototypes(preprocessed_data, n_clusters)
    
    aligned_clusters = align_clusters(assignedclusters, truelabels)
    accuracy = accuracy_score(truelabels, aligned_clusters)
    accuracy_scores.append(accuracy)
    
    adjusted_rand_index = adjusted_rand_score(truelabels, aligned_clusters)
    rand_index_scores.append(adjusted_rand_index)

mean_accuracy_score = np.mean(accuracy_scores)
mean_rand_index_score = np.mean(rand_index_scores)

print("Mean Accuracy Score:", mean_accuracy_score)
print("Mean Adjusted Rand Index Score:", mean_rand_index_score)
# Out:
# Mean Accuracy Score: 0.37038251366120223
# Mean Adjusted Rand Index Score: 0.06425682926716242

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score

data = pd.read_csv('dermatology.csv')
data['family_history'] = data['family_history'].astype('category')
data_encoded = pd.get_dummies(data)
preprocessed_data = data_encoded.copy()
preprocessed_data.drop('class', axis=1, inplace=True)

numerical_cols = data[['age','erythema','scaling','definite_borders','itching','koebner_phenomenon','polygonal_papules','follicular_papules','oral_mucosal_involvement','knee_and_elbow_involvement','scalp_involvement','melanin_incontinence','eosinophils_in_the_infiltrate','pnl_infiltrate','fibrosis_of_the_papillary_dermis','exocytosis','acanthosis','hyperkeratosis','parakeratosis','clubbing_of_the_rete_ridges','elongation_of_the_rete_ridges','thinning_of_the_suprapapillary_epidermis','spongiform_pustule','munro_microabcess','focal_hypergranulosis','disappearance_of_the_granular_layer','vacuolisation_and_damage_of_basal_layer','spongiosis','saw-tooth_appearance_of_retes','follicular_horn_plug','perifollicular_parakeratosis','inflammatory_monoluclear_inflitrate','band-like_infiltrate']]
preprocessed_data = pd.concat([numerical_cols, data_encoded], axis=1)

n_clusters = 6

kmeans = KMeans(n_clusters=n_clusters, n_init=50,verbose=2)
kmeans.fit_predict(preprocessed_data)

accuracy = accuracy_score(truelabels, kmeans.labels_)

adjusted_rand_index = adjusted_rand_score(truelabels, kmeans.labels_)

print("Mean Accuracy Score:", mean_accuracy_score)
print("Mean Adjusted Rand Index Score:", mean_rand_index_score)
# Out:
# Initialization complete
# Iteration 0, inertia 46449.0.
# Iteration 1, inertia 26201.451105145494.
# Iteration 2, inertia 25252.101884546268.
# Iteration 3, inertia 24948.729687126233.
# Iteration 4, inertia 24816.495214006165.
# Iteration 5, inertia 24758.49455539891.
# Iteration 6, inertia 24727.32852747242.
# Iteration 7, inertia 24717.466379527665.
# Iteration 8, inertia 24710.515810395227.
# Converged at iteration 8: strict convergence.
# Initialization complete
# Iteration 0, inertia 41638.0.
# Iteration 1, inertia 29274.053186290395.
# Iteration 2, inertia 28164.240089937663.
# Iteration 3, inertia 27868.691944124083.
# Iteration 4, inertia 27590.987693673815.
# Iteration 5, inertia 27425.57361877284.
# Iteration 6, inertia 27197.184557448272.
# Iteration 7, inertia 26816.89571155611.
# Iteration 8, inertia 26671.549427430182.
# Iteration 9, inertia 26648.240832387302.
# Iteration 10, inertia 26620.65542623319.
# Iteration 11, inertia 26590.656886916746.
# Iteration 12, inertia 26509.27582159204.
# Iteration 13, inertia 26193.166756424867.
# Iteration 14, inertia 25503.539653406504.
# Iteration 15, inertia 25102.176505326082.
# Iteration 16, inertia 24996.153583185613.
# Iteration 17, inertia 24921.70166120589.
# Iteration 18, inertia 24911.428431102144.
# Iteration 19, inertia 24898.44415238453.
# Iteration 20, inertia 24894.61788013673.
# Iteration 21, inertia 24890.27871263918.
# Iteration 22, inertia 24887.419102855038.
# Converged at iteration 22: strict convergence.
# Initialization complete
# Iteration 0, inertia 46631.0.
# Iteration 1, inertia 28568.05495527348.
# Iteration 2, inertia 27549.74745657877.
# Iteration 3, inertia 27023.556206923226.
# Iteration 4, inertia 26950.516113984446.
# Iteration 5, inertia 26926.62158994786.
# Converged at iteration 5: strict convergence.
# Initialization complete
# Iteration 0, inertia
# Iteration 15, inertia 25177.45525863486.
# Iteration 16, inertia 24973.372754282147.
# Iteration 17, inertia 24895.032699613246.
# Iteration 18, inertia 24846.25581470775.
# Iteration 19, inertia 24756.76477900121.
# Iteration 20, inertia 24735.800863638957.
# Iteration 21, inertia 24729.164803834192.
# Iteration 22, inertia 24718.925641647413.
# Iteration 23, inertia 24690.855269642412.
# Iteration 24, inertia 24680.993121697662.
# Iteration 25, inertia 24674.042552565224.
# Converged at iteration 25: strict convergence.
# Initialization complete
# Iteration 0, inertia 46568.0.
# Iteration 1, inertia 29385.000043206528.
# Iteration 2, inertia 28046.05070344817.
# Iteration 3, inertia 27951.54118438531.
# Iteration 4, inertia 27796.38323073081.
# Iteration 5, inertia 27590.511109337585.
# Iteration 6, inertia 27236.73925560927.
# Iteration 7, inertia 27052.824021137698.
# Iteration 8, inertia 26816.190146880082.
# Iteration 9, inertia 26464.795419373037.
# Iteration 10, inertia 26333.88289226392.
# Iteration 11, inertia 26310.724830567426.
# Iteration 12, inertia 26306.419578651057.
# Converged at iteration 12: strict convergence.
# Initialization complete
# Iteration 0, inertia 41403.0.
# Iteration 1, inertia 24869.906797020183.
# Iteration 2, inertia 24727.166760561697.
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 43093.0.
# Iteration 1, inertia 26572.40973151109.
# Iteration 2, inertia 26217.311841511393.
# Iteration 3, inertia 25462.317468708086.
# Iteration 4, inertia 25088.07170542911.
# Iteration 5, inertia 24943.837543364418.
# Iteration 6, inertia 24927.055504192314.
# Iteration 7, inertia 24924.163680572303.
# Converged at iteration 7: strict convergence.
# Initialization complete
# Iteration 0, inertia 47456.0.
# Iteration 1, inertia 26659.614385016954.
# Iteration 2, inertia 25522.20053473773.
# Iteration 3, inertia 25103.41586776786.
# Iteration 4, inertia 24917.764538672724.
# Iteration 5, inertia 24894.61788013673.
# Iteration 6, inertia 24890.27871263918.
# Iteration 7, inertia 24887.419102855038.
# Converged at iteration 7: strict convergence.
# Mean Accuracy Score: 0.37038251366120223
# Mean Adjusted Rand Index Score: 0.06425682926716242

# %%
#Discritizing the numerical columns to use KModes on the heterogeneous data
from sklearn.preprocessing import KBinsDiscretizer
from kmodes.kmodes import KModes
from sklearn.metrics import accuracy_score

# Discretize numerical columns
numerical_cols = data[['age','erythema','scaling','definite_borders','itching','koebner_phenomenon','polygonal_papules','follicular_papules','oral_mucosal_involvement','knee_and_elbow_involvement','scalp_involvement','melanin_incontinence','eosinophils_in_the_infiltrate','pnl_infiltrate','fibrosis_of_the_papillary_dermis','exocytosis','acanthosis','hyperkeratosis','parakeratosis','clubbing_of_the_rete_ridges','elongation_of_the_rete_ridges','thinning_of_the_suprapapillary_epidermis','spongiform_pustule','munro_microabcess','focal_hypergranulosis','disappearance_of_the_granular_layer','vacuolisation_and_damage_of_basal_layer','spongiosis','saw-tooth_appearance_of_retes','follicular_horn_plug','perifollicular_parakeratosis','inflammatory_monoluclear_inflitrate','band-like_infiltrate']].copy()
kbins = KBinsDiscretizer(n_bins=5, encode='ordinal', strategy='uniform')
numerical_cols_discretized = kbins.fit_transform(numerical_cols)

# Combine discretized numerical columns with categorical columns
preprocessed_data = pd.concat([pd.DataFrame(numerical_cols_discretized, columns=['age','erythema','scaling','definite_borders','itching','koebner_phenomenon','polygonal_papules','follicular_papules','oral_mucosal_involvement','knee_and_elbow_involvement','scalp_involvement','melanin_incontinence','eosinophils_in_the_infiltrate','pnl_infiltrate','fibrosis_of_the_papillary_dermis','exocytosis','acanthosis','hyperkeratosis','parakeratosis','clubbing_of_the_rete_ridges','elongation_of_the_rete_ridges','thinning_of_the_suprapapillary_epidermis','spongiform_pustule','munro_microabcess','focal_hypergranulosis','disappearance_of_the_granular_layer','vacuolisation_and_damage_of_basal_layer','spongiosis','saw-tooth_appearance_of_retes','follicular_horn_plug','perifollicular_parakeratosis','inflammatory_monoluclear_inflitrate','band-like_infiltrate']), categorical_cols], axis=1)

km = KModes(n_clusters=n_clusters, init='Huang', n_init=50, verbose=2)
km.fit_predict(preprocessed_data)

accuracy_kmodes = accuracy_score(truelabels, km.labels_)
adjusted_rand_index = adjusted_rand_score(truelabels, km.labels_)

print("Mean Kmodes Accuracy Score:", accuracy_kmodes)
print("Mean Kmodes Adjusted Rand Index Score:", adjusted_rand_index)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 136, cost: 3183.0
# Run 1, iteration: 2/100, moves: 26, cost: 3178.0
# Run 1, iteration: 3/100, moves: 0, cost: 3178.0
# c:\Users\User\anaconda3\envs\kmodestry1\Lib\site-packages\sklearn\preprocessing\_discretization.py:248: FutureWarning: In version 1.5 onwards, subsample=200_000 will be used by default. Set subsample explicitly to silence this warning in the mean time. Set subsample=None to disable subsampling explicitly.
#   warnings.warn(
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 107, cost: 3206.0
# Run 2, iteration: 2/100, moves: 43, cost: 3201.0
# Run 2, iteration: 3/100, moves: 4, cost: 3201.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 152, cost: 3301.0
# Run 3, iteration: 2/100, moves: 82, cost: 3219.0
# Run 3, iteration: 3/100, moves: 20, cost: 3219.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 143, cost: 3289.0
# Run 4, iteration: 2/100, moves: 97, cost: 3204.0
# Run 4, iteration: 3/100, moves: 49, cost: 3196.0
# Run 4, iteration: 4/100, moves: 8, cost: 3196.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 158, cost: 3210.0
# Run 5, iteration: 2/100, moves: 49, cost: 3210.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 6, iteration: 1/100, moves: 140, cost: 3216.0
# Run 6, iteration: 2/100, moves: 50, cost: 3212.0
# Run 6, iteration: 3/100, moves: 1, cost: 3212.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 7, iteration: 1/100, moves: 158, cost: 3230.0
# Run 7, iteration: 2/100, moves: 17, cost: 3230.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 8, iteration: 1/100, moves: 102, cost: 3219.0
# Run 8, iteration: 2/100, moves: 32, cost: 3200.0
# Run 8, iteration: 3/100, moves: 29, cost: 3195.0
# Run 8, iteration: 4/100, moves: 3, cost: 3195.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 9, iteration: 1/100, moves: 131, cost: 3252.0
# Run 9, iteration: 2/100, moves: 56, cost: 3205.0
# Run 9, iteration: 3/100, moves: 10, cost: 3205.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 10, iteration: 1/100, moves: 146, cost: 3211.0
# Run 10, iteration: 2/100, moves: 76, cost: 3187.0
# Run 10, iteration: 3/100, moves: 5, cost: 3187.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 11, iteration: 1/100, moves: 153, cost: 3340.0
# Run 11, iteration: 2/100, moves: 111, cost: 3217.0
# Run 11, iteration: 3/100, moves: 59, cost: 3186.0
# Run 11, iteration: 4/100, moves: 22, cost: 3176.0
# Run 11, iteration: 5/100, moves: 3, cost: 3176.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 12, iteration: 1/100, moves: 148, cost: 2972.0
# Run 12, iteration: 2/100, moves: 52, cost: 2941.0
# Run 12, iteration: 3/100, moves: 18, cost: 2941.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 13, iteration: 1/100, moves: 149, cost: 3235.0
# Run 13, iteration: 2/100, moves: 37, cost: 3220.0
# Run 13, iteration: 3/100, moves: 14, cost: 3220.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 14, iteration: 1/100, moves: 113, cost: 3211.0
# Run 14, iteration: 2/100, moves: 10, cost: 3205.0
# Run 14, iteration: 3/100, moves: 1, cost: 3205.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 15, iteration: 1/100, moves: 158, cost: 3185.0
# Run 15, iteration: 2/100, moves: 52, cost: 3160.0
# Run 15, iteration: 3/100, moves: 9, cost: 3158.0
# Run 15, iteration: 4/100, moves: 1, cost: 3158.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 16, iteration: 1/100, moves: 128, cost: 3329.0
# Run 16, iteration: 2/100, moves: 72, cost: 3217.0
# Run 16, iteration: 3/100, moves: 43, cost: 3190.0
# Run 16, iteration: 4/100, moves: 7, cost: 3190.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 17, iteration: 1/100, moves: 94, cost: 2956.0
# Run 17, iteration: 2/100, moves: 10, cost: 2956.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 18, iteration: 1/100, moves: 88, cost: 3202.0
# Run 18, iteration: 2/100, moves: 2, cost: 3202.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 19, iteration: 1/100, moves: 131, cost: 3204.0
# Run 19, iteration: 2/100, moves: 53, cost: 3176.0
# Run 19, iteration: 3/100, moves: 12, cost: 3176.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 20, iteration: 1/100, moves: 123, cost: 3173.0
# Run 20, iteration: 2/100, moves: 32, cost: 3171.0
# Run 20, iteration: 3/100, moves: 8, cost: 3171.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 21, iteration: 1/100, moves: 168, cost: 3236.0
# Run 21, iteration: 2/100, moves: 77, cost: 3200.0
# Run 21, iteration: 3/100, moves: 10, cost: 3200.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 22, iteration: 1/100, moves: 118, cost: 3239.0
# Run 22, iteration: 2/100, moves: 26, cost: 3239.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 23, iteration: 1/100, moves: 162, cost: 3198.0
# Run 23, iteration: 2/100, moves: 53, cost: 3191.0
# Run 23, iteration: 3/100, moves: 1, cost: 3191.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 24, iteration: 1/100, moves: 86, cost: 3213.0
# Run 24, iteration: 2/100, moves: 11, cost: 3213.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 25, iteration: 1/100, moves: 145, cost: 3270.0
# Run 25, iteration: 2/100, moves: 75, cost: 3214.0
# Run 25, iteration: 3/100, moves: 14, cost: 3214.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 26, iteration: 1/100, moves: 149, cost: 3229.0
# Run 26, iteration: 2/100, moves: 50, cost: 3210.0
# Run 26, iteration: 3/100, moves: 0, cost: 3210.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 27, iteration: 1/100, moves: 89, cost: 3258.0
# Run 27, iteration: 2/100, moves: 59, cost: 3246.0
# Run 27, iteration: 3/100, moves: 26, cost: 3232.0
# Run 27, iteration: 4/100, moves: 20, cost: 3221.0
# Run 27, iteration: 5/100, moves: 1, cost: 3221.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 28, iteration: 1/100, moves: 102, cost: 3191.0
# Run 28, iteration: 2/100, moves: 24, cost: 3191.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 29, iteration: 1/100, moves: 110, cost: 3055.0
# Run 29, iteration: 2/100, moves: 65, cost: 3001.0
# Run 29, iteration: 3/100, moves: 27, cost: 2955.0
# Run 29, iteration: 4/100, moves: 17, cost: 2945.0
# Run 29, iteration: 5/100, moves: 7, cost: 2945.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 30, iteration: 1/100, moves: 131, cost: 3204.0
# Run 30, iteration: 2/100, moves: 27, cost: 3204.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 31, iteration: 1/100, moves: 114, cost: 3156.0
# Run 31, iteration: 2/100, moves: 11, cost: 3156.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 32, iteration: 1/100, moves: 130, cost: 3198.0
# Run 32, iteration: 2/100, moves: 40, cost: 3198.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 33, iteration: 1/100, moves: 131, cost: 3219.0
# Run 33, iteration: 2/100, moves: 7, cost: 3219.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 34, iteration: 1/100, moves: 132, cost: 3232.0
# Run 34, iteration: 2/100, moves: 1, cost: 3232.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 35, iteration: 1/100, moves: 140, cost: 3238.0
# Run 35, iteration: 2/100, moves: 50, cost: 3213.0
# Run 35, iteration: 3/100, moves: 24, cost: 3213.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 36, iteration: 1/100, moves: 108, cost: 3153.0
# Run 36, iteration: 2/100, moves: 15, cost: 3153.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 37, iteration: 1/100, moves: 93, cost: 3185.0
# Run 37, iteration: 2/100, moves: 21, cost: 3182.0
# Run 37, iteration: 3/100, moves: 1, cost: 3182.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 38, iteration: 1/100, moves: 110, cost: 3195.0
# Run 38, iteration: 2/100, moves: 30, cost: 3188.0
# Run 38, iteration: 3/100, moves: 3, cost: 3188.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 39, iteration: 1/100, moves: 156, cost: 3220.0
# Run 39, iteration: 2/100, moves: 72, cost: 3194.0
# Run 39, iteration: 3/100, moves: 12, cost: 3194.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 40, iteration: 1/100, moves: 99, cost: 3186.0
# Run 40, iteration: 2/100, moves: 25, cost: 3183.0
# Run 40, iteration: 3/100, moves: 5, cost: 3183.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 41, iteration: 1/100, moves: 102, cost: 3195.0
# Run 41, iteration: 2/100, moves: 27, cost: 3194.0
# Run 41, iteration: 3/100, moves: 6, cost: 3194.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 42, iteration: 1/100, moves: 129, cost: 3199.0
# Run 42, iteration: 2/100, moves: 86, cost: 2981.0
# Run 42, iteration: 3/100, moves: 57, cost: 2935.0
# Run 42, iteration: 4/100, moves: 32, cost: 2912.0
# Run 42, iteration: 5/100, moves: 15, cost: 2898.0
# Run 42, iteration: 6/100, moves: 17, cost: 2898.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 43, iteration: 1/100, moves: 157, cost: 3253.0
# Run 43, iteration: 2/100, moves: 91, cost: 3182.0
# Run 43, iteration: 3/100, moves: 22, cost: 3173.0
# Run 43, iteration: 4/100, moves: 9, cost: 3172.0
# Run 43, iteration: 5/100, moves: 0, cost: 3172.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 44, iteration: 1/100, moves: 115, cost: 2980.0
# Run 44, iteration: 2/100, moves: 12, cost: 2976.0
# Run 44, iteration: 3/100, moves: 9, cost: 2962.0
# Run 44, iteration: 4/100, moves: 36, cost: 2948.0
# Run 44, iteration: 5/100, moves: 28, cost: 2929.0
# Run 44, iteration: 6/100, moves: 14, cost: 2929.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 45, iteration: 1/100, moves: 113, cost: 2940.0
# Run 45, iteration: 2/100, moves: 56, cost: 2912.0
# Run 45, iteration: 3/100, moves: 17, cost: 2908.0
# Run 45, iteration: 4/100, moves: 8, cost: 2905.0
# Run 45, iteration: 5/100, moves: 2, cost: 2905.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 46, iteration: 1/100, moves: 79, cost: 2948.0
# Run 46, iteration: 2/100, moves: 24, cost: 2942.0
# Run 46, iteration: 3/100, moves: 0, cost: 2942.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 47, iteration: 1/100, moves: 140, cost: 3221.0
# Run 47, iteration: 2/100, moves: 18, cost: 3221.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 48, iteration: 1/100, moves: 164, cost: 3249.0
# Run 48, iteration: 2/100, moves: 39, cost: 3231.0
# Run 48, iteration: 3/100, moves: 19, cost: 3227.0
# Run 48, iteration: 4/100, moves: 0, cost: 3227.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 49, iteration: 1/100, moves: 145, cost: 3262.0
# Run 49, iteration: 2/100, moves: 43, cost: 3242.0
# Run 49, iteration: 3/100, moves: 11, cost: 3226.0
# Run 49, iteration: 4/100, moves: 12, cost: 3226.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 50, iteration: 1/100, moves: 114, cost: 3243.0
# Run 50, iteration: 2/100, moves: 44, cost: 3190.0
# Run 50, iteration: 3/100, moves: 18, cost: 3184.0
# Run 50, iteration: 4/100, moves: 2, cost: 3184.0
# Best run was number 42
# Mean Kmodes Accuracy Score: 0.5491803278688525
# Mean Kmodes Adjusted Rand Index Score: 0.6215064803878718
